# %% [markdown]
# ### Pandas nlargest(), nsmallest(), query() and where() methods

# %% [markdown]
# https://medium.com/@tderick/become-a-pandas-ninja-with-nlargest-nsmallest-query-and-where-methods-490ab97bbe99

# %% [markdown]
# Throughout this article with this dataset, we’ll explore nlargest(), nsmallest(), query() and where() methods.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('https://raw.githubusercontent.com/tderick/datainsightonelineprogram/main/pandas%20technique%20for%20datascience%20blog%202/Participated%20Teams%20General%20Statistics.csv')

# %%
df
# Out:
#     Rank               Team  Titles  Part's  Played  Win  Draw  Lose  \
# 0      1              Egypt     7.0      24     100   57    17    26
# 1      2              Ghana     4.0      22      99   54    20    25
# 2      3            Nigeria     3.0      18      93   51    21    21
# 3      4        Ivory Coast     2.0      23      95   42    25    28
# 4      5           Cameroon     5.0      19      84   41    27    16
# 5      6            Algeria     2.0      18      74   28    21    25
# 6      7             Zambia     1.0      17      67   26    20    21
# 7      8            Tunisia     1.0      19      75   23    29    23
# 8      9            Morocco     1.0      17      65   24    23    18
# 9     10           DR Congo     2.0      19      73   20    24    29
# 10    11            Senegal     NaN      15      60   23    14    23
# 11    12               Mali     NaN      11      50   17    17    16
# 12    13       South Africa     1.0      10      42   16    13    14
# 13    14             Guinea     NaN      12      43   12    16    15
# 14    15       Burkina Faso     NaN      11      41    7    13    21
# 15    16              Congo     1.0       7      26    7     7    12
# 16    17              Sudan     1.0       8      24    7     6    11
# 17    18              Gabon     NaN       7      21    6     7     8
# 18    19             Angola     NaN       8      26    4    12    10
# 19    20           Ethiopia     1.0      10      27    7     3    17
# 20    21               Togo     NaN       8      25    3     8    14
# 21    22  Equatorial Guinea     NaN       2      10    4     3     3
# 22    23             Uganda     NaN       7      23    4     3    16
# 23    24              Libya     NaN       3      11    3     5     3
# 24    25              Kenya     NaN       6      17    2     4    11
# 25    26         Madagascar     NaN       1       5    2     2     1
# 26    27         Cape Verde     NaN       2       7    1     5     1
# 27    28           Zimbabwe     NaN       4      12    2     2     8
# 28    29            Liberia     NaN       2       5    1     2     2
# 29    30              Benin     NaN       4      14    0     5     9
# 30    31             Rwanda     NaN       1       3    1     1     1
# 31    32             Malawi     NaN       2       6    1     1     4
# 32    33       Sierra Leone     NaN       2       5    1     1     3
# 33    34         Mauritania     NaN       1       3    0     2     1
# 34    35      Guinea-Bissau     NaN       2       6    0     2     4
# 35    36            Namibia     NaN       3       9    0     2     7
# 36    37         Mozambique     NaN       4      12    0     2    10
# 37    38              Niger     NaN       2       6    0     1     5
# 38    39           Tanzania     NaN       2       6    0     1     5
# 39    40            Burundi     NaN       1       3    0     0     3
# 40    41          Mauritius     NaN       1       3    0     0     3
# 41    42           Botswana     NaN       1       3    0     0     3
#
#     Goal_For  Goal_Against  Goal_Difference  Points  Points%
# 0        164            88               76     188     62.7
# 1        130            82               48     182     61.3
# 2        132            89               43     174     62.4
# 3        138           100               38     151     53.0
# 4        123            76               47     150     59.5
# 5         93            85                8     105     47.3
# 6         81            69               12      98     48.8
# 7         94            91                3      98     43.5
# 8         74            58               16      95     48.7
# 9         88           102               14      84     38.3
# 10        69            54               15      83     46.1
# 11        61            64                3      68     45.3
# 12        48            45                3      61     48.4
# 13        59            63                4      52     40.3
# 14        38            62               24      34     27.6
# 15        27            40               13      28     35.9
# 16        28            38               10      27     37.5
# 17        19            26                7      25     39.7
# 18        30            39                9      24     30.7
# 19        29            61               32      24     29.6
# 20        19            42               23      17     22.7
# 21         8            10                2      15     50.0
# 22        21            38               17      15     21.7
# 23        12            13                1      14     42.4
# 24        12            31               20      10     19.6
# 25         7             7                0       8     53.3
# 26         4             5                1       8     38.1
# 27        13            27               14       8     22.2
# 28         5             7                2       5     33.3
# 29         7            24               17       5     11.9
# 30         3             3                0       4     44.4
# 31         6            11                5       4     22.2
# 32         2            11                9       4     26.7
# 33         1             4                3       2     22.2
# 34         2             9                7       2     11.1
# 35        10            24               14       2      7.4
# 36         4            26               22       2      5.6
# 37         1             9                8       1      5.6
# 38         5            14                9       1      5.5
# 39         0             4                4       0      0.0
# 40         2             8                6       0      0.0
# 41         2             9                7       0      0.0

# %% [markdown]
# ### 1. DataFrame.nlargest() and DataFrame.nsmallest()

# %% [markdown]
# __DataFrame.nlargest()__ is a pandas method that ordered DataFrame in descending order and takes the first n rows. The signature of this method is:
#
# DataFrame.nlargest(n, columns, keep ="first")
#
# where
#
# * __columns__ is a list of columns to use sort DataFrame in descending order
#
# * __keep__ indicate the occurences of duplicate rows to conserve .This parameter takes value in the  set __first__, __last__, __all__
#
# * __n__ indicate the number rows to take after sorting the DataFrame

# %%
df.nlargest(5, columns="Rank")
# Out:
#     Rank       Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 41    42   Botswana     NaN       1       3    0     0     3         2
# 40    41  Mauritius     NaN       1       3    0     0     3         2
# 39    40    Burundi     NaN       1       3    0     0     3         0
# 38    39   Tanzania     NaN       2       6    0     1     5         5
# 37    38      Niger     NaN       2       6    0     1     5         1
#
#     Goal_Against  Goal_Difference  Points  Points%
# 41             9                7       0      0.0
# 40             8                6       0      0.0
# 39             4                4       0      0.0
# 38            14                9       1      5.5
# 37             9                8       1      5.6

# %% [markdown]
# The image shows us clearly that __enlargest()__ method sort DataFrame in descending  order and take the first 5 elements. You can add keep
# parameter to tell __enlargest()__ method to do infront of duplicate rows. The default value for __keep__ is __first__

# %%
df.nlargest(5, columns="Rank", keep="first") #  keep first is default
# Out:
#     Rank       Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 41    42   Botswana     NaN       1       3    0     0     3         2
# 40    41  Mauritius     NaN       1       3    0     0     3         2
# 39    40    Burundi     NaN       1       3    0     0     3         0
# 38    39   Tanzania     NaN       2       6    0     1     5         5
# 37    38      Niger     NaN       2       6    0     1     5         1
#
#     Goal_Against  Goal_Difference  Points  Points%
# 41             9                7       0      0.0
# 40             8                6       0      0.0
# 39             4                4       0      0.0
# 38            14                9       1      5.5
# 37             9                8       1      5.6

# %%
df.nlargest(5, columns="Rank", keep="last")
# Out:
#     Rank       Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 41    42   Botswana     NaN       1       3    0     0     3         2
# 40    41  Mauritius     NaN       1       3    0     0     3         2
# 39    40    Burundi     NaN       1       3    0     0     3         0
# 38    39   Tanzania     NaN       2       6    0     1     5         5
# 37    38      Niger     NaN       2       6    0     1     5         1
#
#     Goal_Against  Goal_Difference  Points  Points%
# 41             9                7       0      0.0
# 40             8                6       0      0.0
# 39             4                4       0      0.0
# 38            14                9       1      5.5
# 37             9                8       1      5.6

# %%
df.nlargest(5, columns="Rank", keep="all")
# Out:
#     Rank       Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 41    42   Botswana     NaN       1       3    0     0     3         2
# 40    41  Mauritius     NaN       1       3    0     0     3         2
# 39    40    Burundi     NaN       1       3    0     0     3         0
# 38    39   Tanzania     NaN       2       6    0     1     5         5
# 37    38      Niger     NaN       2       6    0     1     5         1
#
#     Goal_Against  Goal_Difference  Points  Points%
# 41             9                7       0      0.0
# 40             8                6       0      0.0
# 39             4                4       0      0.0
# 38            14                9       1      5.5
# 37             9                8       1      5.6

# %% [markdown]
# To sort our DataFrame in ascending order and get the first n rows, pandas provide another method to do that: __DataFrame.nsmallest()__. The signature of this method is:
#
# DataFrame.nsmallest(n, columns, keep ="first")
#
# This method takes the same parameter as __nlargest()__ but works in an inverse way.

# %%
 df.nsmallest(5, columns="Rank")
# Out:
#    Rank         Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 0     1        Egypt     7.0      24     100   57    17    26       164
# 1     2        Ghana     4.0      22      99   54    20    25       130
# 2     3      Nigeria     3.0      18      93   51    21    21       132
# 3     4  Ivory Coast     2.0      23      95   42    25    28       138
# 4     5     Cameroon     5.0      19      84   41    27    16       123
#
#    Goal_Against  Goal_Difference  Points  Points%
# 0            88               76     188     62.7
# 1            82               48     182     61.3
# 2            89               43     174     62.4
# 3           100               38     151     53.0
# 4            76               47     150     59.5

# %% [markdown]
# The result DataFrame in this case is ordered in ascending order based on columns we specify.
#
# In this section, we talk about nlargest and nsmallest which are pretty useful and easy when working with pandas. In the next section, we’ll talk about __DataFrame.query()__.

# %% [markdown]
# ### 2.DataFrame query

# %% [markdown]
# This method is a pandas shortcut  for filtering DataFrame.It allows us to query Dataframe columns with a boolean expression.The signature of this method is :
#
# DataFrame.query(expr, inplace=False, **kwargs)
#
# where
#
# * __expr__ is string to evaluate
#
# * __inplace__ indicate if we’ll work on a copy of DataFrame or not

# %%
df.query("Win > 20")
# Out:
#     Rank         Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 0      1        Egypt     7.0      24     100   57    17    26       164
# 1      2        Ghana     4.0      22      99   54    20    25       130
# 2      3      Nigeria     3.0      18      93   51    21    21       132
# 3      4  Ivory Coast     2.0      23      95   42    25    28       138
# 4      5     Cameroon     5.0      19      84   41    27    16       123
# 5      6      Algeria     2.0      18      74   28    21    25        93
# 6      7       Zambia     1.0      17      67   26    20    21        81
# 7      8      Tunisia     1.0      19      75   23    29    23        94
# 8      9      Morocco     1.0      17      65   24    23    18        74
# 10    11      Senegal     NaN      15      60   23    14    23        69
#
#     Goal_Against  Goal_Difference  Points  Points%
# 0             88               76     188     62.7
# 1             82               48     182     61.3
# 2             89               43     174     62.4
# 3            100               38     151     53.0
# 4             76               47     150     59.5
# 5             85                8     105     47.3
# 6             69               12      98     48.8
# 7             91                3      98     43.5
# 8             58               16      95     48.7
# 10            54               15      83     46.1

# %% [markdown]
# The previous line of code return all entries where the number of matches played is greater than 20. We can combine multiple conditions in the same expression.

# %%
display(df.query("Win > 20 and Lose < 20"))
display(df.query("Win > 20 & Lose < 20"))
# Out:
#    Rank      Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 4     5  Cameroon     5.0      19      84   41    27    16       123
# 8     9   Morocco     1.0      17      65   24    23    18        74
#
#    Goal_Against  Goal_Difference  Points  Points%
# 4            76               47     150     59.5
# 8            58               16      95     48.7
#    Rank      Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 4     5  Cameroon     5.0      19      84   41    27    16       123
# 8     9   Morocco     1.0      17      65   24    23    18        74
#
#    Goal_Against  Goal_Difference  Points  Points%
# 4            76               47     150     59.5
# 8            58               16      95     48.7

# %% [markdown]
# We have various boolean operator to use to combine different condition in our expression.
#
# * __and with equivalent &__
# * __or with his equivalent |__
# * __not with his equivalent ~__

# %% [markdown]
# We can find all African countries which have never win a African Cup of Nation like this:

# %%
display(df.query("~(Titles>= 1)"))
display(df.query("not(Titles>= 1)"))
# Out:
#     Rank               Team  Titles  Part's  Played  Win  Draw  Lose  \
# 10    11            Senegal     NaN      15      60   23    14    23
# 11    12               Mali     NaN      11      50   17    17    16
# 13    14             Guinea     NaN      12      43   12    16    15
# 14    15       Burkina Faso     NaN      11      41    7    13    21
# 17    18              Gabon     NaN       7      21    6     7     8
# 18    19             Angola     NaN       8      26    4    12    10
# 20    21               Togo     NaN       8      25    3     8    14
# 21    22  Equatorial Guinea     NaN       2      10    4     3     3
# 22    23             Uganda     NaN       7      23    4     3    16
# 23    24              Libya     NaN       3      11    3     5     3
# 24    25              Kenya     NaN       6      17    2     4    11
# 25    26         Madagascar     NaN       1       5    2     2     1
# 26    27         Cape Verde     NaN       2       7    1     5     1
# 27    28           Zimbabwe     NaN       4      12    2     2     8
# 28    29            Liberia     NaN       2       5    1     2     2
# 29    30              Benin     NaN       4      14    0     5     9
# 30    31             Rwanda     NaN       1       3    1     1     1
# 31    32             Malawi     NaN       2       6    1     1     4
# 32    33       Sierra Leone     NaN       2       5    1     1     3
# 33    34         Mauritania     NaN       1       3    0     2     1
# 34    35      Guinea-Bissau     NaN       2       6    0     2     4
# 35    36            Namibia     NaN       3       9    0     2     7
# 36    37         Mozambique     NaN       4      12    0     2    10
# 37    38              Niger     NaN       2       6    0     1     5
# 38    39           Tanzania     NaN       2       6    0     1     5
# 39    40            Burundi     NaN       1       3    0     0     3
# 40    41          Mauritius     NaN       1       3    0     0     3
# 41    42           Botswana     NaN       1       3    0     0     3
#
#     Goal_For  Goal_Against  Goal_Difference  Points  Points%
# 10        69            54               15      83     46.1
# 11        61            64                3      68     45.3
# 13        59            63                4      52     40.3
# 14        38            62               24      34     27.6
# 17        19            26                7      25     39.7
# 18        30            39                9      24     30.7
# 20        19            42               23      17     22.7
# 21         8            10                2      15     50.0
# 22        21            38               17      15     21.7
# 23        12            13                1      14     42.4
# 24        12            31               20      10     19.6
# 25         7             7                0       8     53.3
# 26         4             5                1       8     38.1
# 27        13            27               14       8     22.2
# 28         5             7                2       5     33.3
# 29         7            24               17       5     11.9
# 30         3             3                0       4     44.4
# 31         6            11                5       4     22.2
# 32         2            11                9       4     26.7
# 33         1             4                3       2     22.2
# 34         2             9                7       2     11.1
# 35        10            24               14       2      7.4
# 36         4            26               22       2      5.6
# 37         1             9                8       1      5.6
# 38         5            14                9       1      5.5
# 39         0             4                4       0      0.0
# 40         2             8                6       0      0.0
# 41         2             9                7       0      0.0
#     Rank               Team  Titles  Part's  Played  Win  Draw  Lose  \
# 10    11            Senegal     NaN      15      60   23    14    23
# 11    12               Mali     NaN      11      50   17    17    16
# 13    14             Guinea     NaN      12      43   12    16    15
# 14    15       Burkina Faso     NaN      11      41    7    13    21
# 17    18              Gabon     NaN       7      21    6     7     8
# 18    19             Angola     NaN       8      26    4    12    10
# 20    21               Togo     NaN       8      25    3     8    14
# 21    22  Equatorial Guinea     NaN       2      10    4     3     3
# 22    23             Uganda     NaN       7      23    4     3    16
# 23    24              Libya     NaN       3      11    3     5     3
# 24    25              Kenya     NaN       6      17    2     4    11
# 25    26         Madagascar     NaN       1       5    2     2     1
# 26    27         Cape Verde     NaN       2       7    1     5     1
# 27    28           Zimbabwe     NaN       4      12    2     2     8
# 28    29            Liberia     NaN       2       5    1     2     2
# 29    30              Benin     NaN       4      14    0     5     9
# 30    31             Rwanda     NaN       1       3    1     1     1
# 31    32             Malawi     NaN       2       6    1     1     4
# 32    33       Sierra Leone     NaN       2       5    1     1     3
# 33    34         Mauritania     NaN       1       3    0     2     1
# 34    35      Guinea-Bissau     NaN       2       6    0     2     4
# 35    36            Namibia     NaN       3       9    0     2     7
# 36    37         Mozambique     NaN       4      12    0     2    10
# 37    38              Niger     NaN       2       6    0     1     5
# 38    39           Tanzania     NaN       2       6    0     1     5
# 39    40            Burundi     NaN       1       3    0     0     3
# 40    41          Mauritius     NaN       1       3    0     0     3
# 41    42           Botswana     NaN       1       3    0     0     3
#
#     Goal_For  Goal_Against  Goal_Difference  Points  Points%
# 10        69            54               15      83     46.1
# 11        61            64                3      68     45.3
# 13        59            63                4      52     40.3
# 14        38            62               24      34     27.6
# 17        19            26                7      25     39.7
# 18        30            39                9      24     30.7
# 20        19            42               23      17     22.7
# 21         8            10                2      15     50.0
# 22        21            38               17      15     21.7
# 23        12            13                1      14     42.4
# 24        12            31               20      10     19.6
# 25         7             7                0       8     53.3
# 26         4             5                1       8     38.1
# 27        13            27               14       8     22.2
# 28         5             7                2       5     33.3
# 29         7            24               17       5     11.9
# 30         3             3                0       4     44.4
# 31         6            11                5       4     22.2
# 32         2            11                9       4     26.7
# 33         1             4                3       2     22.2
# 34         2             9                7       2     11.1
# 35        10            24               14       2      7.4
# 36         4            26               22       2      5.6
# 37         1             9                8       1      5.6
# 38         5            14                9       1      5.5
# 39         0             4                4       0      0.0
# 40         2             8                6       0      0.0
# 41         2             9                7       0      0.0

# %%
# To query all African countries with a number of Win greater than 20 and the number of lost less than 20, we write this condition:

df.query("Win > 20 and Lose < 20 ")
# Out:
#    Rank      Team  Titles  Part's  Played  Win  Draw  Lose  Goal_For  \
# 4     5  Cameroon     5.0      19      84   41    27    16       123
# 8     9   Morocco     1.0      17      65   24    23    18        74
#
#    Goal_Against  Goal_Difference  Points  Points%
# 4            76               47     150     59.5
# 8            58               16      95     48.7

# %% [markdown]
# ### 3. DataFrame.where

# %% [markdown]
# DataFrame.where() is another method offered by pandas that are not regularly used but can be useful in certain cases. This method replaces values for which our condition is evaluated to False. In other words, it replaces all values that do not satisfy one or more criteria by the one we give or with NaN by default. The signature of this method is :
#
# DataFrame.where(cond, other=nan, inplace=False, axis = None, level = None, errors = "raise", try_cast = NoDefault.no_default)
#
# where
#
# * __cond__ is the condition to be satisfy by each entries. This condition can a boolean Series/DataFrame, array-like, or callable
#
# * __other__  specify the value to give to each cell where the evaluation of condition is __False__

# %%
# For the following example, we will drop column Team to only have a DataFrame with numerical values.

# %%
df.drop("Team",axis =1 ,inplace=True)

# %%
df.where(df<100,"HIGHT").head(10)
# Out:
#    Rank Titles  Part's Played  Win  Draw  Lose Goal_For Goal_Against  \
# 0     1    7.0      24  HIGHT   57    17    26    HIGHT           88
# 1     2    4.0      22     99   54    20    25    HIGHT           82
# 2     3    3.0      18     93   51    21    21    HIGHT           89
# 3     4    2.0      23     95   42    25    28    HIGHT        HIGHT
# 4     5    5.0      19     84   41    27    16    HIGHT           76
# 5     6    2.0      18     74   28    21    25       93           85
# 6     7    1.0      17     67   26    20    21       81           69
# 7     8    1.0      19     75   23    29    23       94           91
# 8     9    1.0      17     65   24    23    18       74           58
# 9    10    2.0      19     73   20    24    29       88        HIGHT
#
#    Goal_Difference Points Points%
# 0               76  HIGHT    62.7
# 1               48  HIGHT    61.3
# 2               43  HIGHT    62.4
# 3               38  HIGHT    53.0
# 4               47  HIGHT    59.5
# 5                8  HIGHT    47.3
# 6               12     98    48.8
# 7                3     98    43.5
# 8               16     95    48.7
# 9               14     84    38.3

# %%
df.where(df<100,"küçük").head(10)
# Out:
#    Rank Titles  Part's Played  Win  Draw  Lose Goal_For Goal_Against  \
# 0     1    7.0      24  küçük   57    17    26    küçük           88
# 1     2    4.0      22     99   54    20    25    küçük           82
# 2     3    3.0      18     93   51    21    21    küçük           89
# 3     4    2.0      23     95   42    25    28    küçük        küçük
# 4     5    5.0      19     84   41    27    16    küçük           76
# 5     6    2.0      18     74   28    21    25       93           85
# 6     7    1.0      17     67   26    20    21       81           69
# 7     8    1.0      19     75   23    29    23       94           91
# 8     9    1.0      17     65   24    23    18       74           58
# 9    10    2.0      19     73   20    24    29       88        küçük
#
#    Goal_Difference Points Points%
# 0               76  küçük    62.7
# 1               48  küçük    61.3
# 2               43  küçük    62.4
# 3               38  küçük    53.0
# 4               47  küçük    59.5
# 5                8  küçük    47.3
# 6               12     98    48.8
# 7                3     98    43.5
# 8               16     95    48.7
# 9               14     84    38.3

# %% [markdown]
# If we don’t set other parameter, the False entries will be replaced by NaN.

# %%
df.where(df < 100).head()
# Out:
#    Rank  Titles  Part's  Played  Win  Draw  Lose  Goal_For  Goal_Against  \
# 0     1     7.0      24     NaN   57    17    26       NaN          88.0
# 1     2     4.0      22    99.0   54    20    25       NaN          82.0
# 2     3     3.0      18    93.0   51    21    21       NaN          89.0
# 3     4     2.0      23    95.0   42    25    28       NaN           NaN
# 4     5     5.0      19    84.0   41    27    16       NaN          76.0
#
#    Goal_Difference  Points  Points%
# 0               76     NaN     62.7
# 1               48     NaN     61.3
# 2               43     NaN     62.4
# 3               38     NaN     53.0
# 4               47     NaN     59.5

# %%
# We can achieve the same as previous using a callback function in the first parameter of where method.

df.where(lambda x : x < 100, "Ok").head()
# Out:
#    Rank Titles  Part's Played  Win  Draw  Lose Goal_For Goal_Against  \
# 0     1    7.0      24     Ok   57    17    26       Ok           88
# 1     2    4.0      22     99   54    20    25       Ok           82
# 2     3    3.0      18     93   51    21    21       Ok           89
# 3     4    2.0      23     95   42    25    28       Ok           Ok
# 4     5    5.0      19     84   41    27    16       Ok           76
#
#    Goal_Difference Points Points%
# 0               76     Ok    62.7
# 1               48     Ok    61.3
# 2               43     Ok    62.4
# 3               38     Ok    53.0
# 4               47     Ok    59.5

# %% [markdown]
# ### Conclusion

# %% [markdown]
# we give an overview of how nlargest(), nsmallest(), query() and where() methods work. For more examples, you can check pandas documentation for each method. The source code used for this article is avalaible here.
# https://github.com/tderick/datainsightonelineprogram/tree/main/pandas%20technique%20for%20datascience%20blog%204
