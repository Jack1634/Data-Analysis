# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
date_rng = pd.date_range(start = "1/1/2018", end="1/8/2018", freq="H")

# %%
date_rng
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00', '2018-01-01 03:00:00',
#                '2018-01-01 04:00:00', '2018-01-01 05:00:00',
#                '2018-01-01 06:00:00', '2018-01-01 07:00:00',
#                '2018-01-01 08:00:00', '2018-01-01 09:00:00',
#                ...
#                '2018-01-07 15:00:00', '2018-01-07 16:00:00',
#                '2018-01-07 17:00:00', '2018-01-07 18:00:00',
#                '2018-01-07 19:00:00', '2018-01-07 20:00:00',
#                '2018-01-07 21:00:00', '2018-01-07 22:00:00',
#                '2018-01-07 23:00:00', '2018-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq='H')

# %%
type(date_rng[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df= pd.DataFrame(date_rng, columns=["date"])

# %%
df["data"] = np.random.randint(0,100,size=(len(date_rng)))

# %%
df.head(15)
# Out:
#                   date  data
# 0  2018-01-01 00:00:00     6
# 1  2018-01-01 01:00:00    51
# 2  2018-01-01 02:00:00    20
# 3  2018-01-01 03:00:00    57
# 4  2018-01-01 04:00:00    77
# 5  2018-01-01 05:00:00    77
# 6  2018-01-01 06:00:00     0
# 7  2018-01-01 07:00:00    51
# 8  2018-01-01 08:00:00    84
# 9  2018-01-01 09:00:00    71
# 10 2018-01-01 10:00:00    60
# 11 2018-01-01 11:00:00    79
# 12 2018-01-01 12:00:00    37
# 13 2018-01-01 13:00:00    40
# 14 2018-01-01 14:00:00    72

# %%
# If we want to do time series manipulation, we’ll need to have a date time index so that our data frame is indexed 
# on the timestamp.

# %%
# Convert the data frame index to a datetime index then show the first elements:


df["datetime"] = pd.to_datetime(df["date"])
df = df.set_index("datetime")
df.drop(["date"], axis=1, inplace=True)
df.head()
# Out:
#                      data
# datetime
# 2018-01-01 00:00:00     6
# 2018-01-01 01:00:00    51
# 2018-01-01 02:00:00    20
# 2018-01-01 03:00:00    57
# 2018-01-01 04:00:00    77

# %%
string_date_rng = [str(x) for x in date_rng]
string_date_rng
# Out:
# ['2018-01-01 00:00:00',
#  '2018-01-01 01:00:00',
#  '2018-01-01 02:00:00',
#  '2018-01-01 03:00:00',
#  '2018-01-01 04:00:00',
#  '2018-01-01 05:00:00',
#  '2018-01-01 06:00:00',
#  '2018-01-01 07:00:00',
#  '2018-01-01 08:00:00',
#  '2018-01-01 09:00:00',
#  '2018-01-01 10:00:00',
#  '2018-01-01 11:00:00',
#  '2018-01-01 12:00:00',
#  '2018-01-01 13:00:00',
#  '2018-01-01 14:00:00',
#  '2018-01-01 15:00:00',
#  '2018-01-01 16:00:00',
#  '2018-01-01 17:00:00',
#  '2018-01-01 18:00:00',
#  '2018-01-01 19:00:00',
#  '2018-01-01 20:00:00',
#  '2018-01-01 21:00:00',
#  '2018-01-01 22:00:00',
#  '2018-01-01 23:00:00',
#  '2018-01-02 00:00:00',
#  '2018-01-02 01:00:00',
#  '2018-01-02 02:00:00',
#  '2018-01-02 03:00:00',
#  '2018-01-02 04:00:00',
#  '2018-01-02 05:00:00',
#  '2018-01-02 06:00:00',
#  '2018-01-02 07:00:00',
#  '2018-01-02 08:00:00',
#  '2018-01-02 09:00:00',
#  '2018-01-02 10:00:00',
#  '2018-01-02 11:00:00',
#  '2018-01-02 12:00:00',
#  '2018-01-02 13:00:00',
# ...

# %%
# convert the strings to timestamps 
timestamp_date_rng = pd.to_datetime(string_date_rng, infer_datetime_format=True)
timestamp_date_rng
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00', '2018-01-01 03:00:00',
#                '2018-01-01 04:00:00', '2018-01-01 05:00:00',
#                '2018-01-01 06:00:00', '2018-01-01 07:00:00',
#                '2018-01-01 08:00:00', '2018-01-01 09:00:00',
#                ...
#                '2018-01-07 15:00:00', '2018-01-07 16:00:00',
#                '2018-01-07 17:00:00', '2018-01-07 18:00:00',
#                '2018-01-07 19:00:00', '2018-01-07 20:00:00',
#                '2018-01-07 21:00:00', '2018-01-07 22:00:00',
#                '2018-01-07 23:00:00', '2018-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq=None)

# %%
# But what about if we need to convert a unique string format?

# Let’s create an arbitrary list of dates that are strings and convert them to timestamps:

# %%
string_date_rng_2 = ['June-01-2018', 'June-02-2018', 'June-03-2018']
timestamp_date_rng_2 = [datetime.strptime(x,'%B-%d-%Y') for x in string_date_rng_2]
timestamp_date_rng_2
# Out:
# [datetime.datetime(2018, 6, 1, 0, 0),
#  datetime.datetime(2018, 6, 2, 0, 0),
#  datetime.datetime(2018, 6, 3, 0, 0)]

# %%
df2 = pd.DataFrame (timestamp_date_rng_2, columns=["date"])
df2
# Out:
#         date
# 0 2018-06-01
# 1 2018-06-02
# 2 2018-06-03

# %%
df[df.index.day==2]
# Out:
#                      data
# datetime
# 2018-01-02 00:00:00    40
# 2018-01-02 01:00:00    11
# 2018-01-02 02:00:00    39
# 2018-01-02 03:00:00    37
# 2018-01-02 04:00:00    78
# 2018-01-02 05:00:00    66
# 2018-01-02 06:00:00    61
# 2018-01-02 07:00:00     8
# 2018-01-02 08:00:00    86
# 2018-01-02 09:00:00    77
# 2018-01-02 10:00:00    71
# 2018-01-02 11:00:00    57
# 2018-01-02 12:00:00    31
# 2018-01-02 13:00:00    26
# 2018-01-02 14:00:00    19
# 2018-01-02 15:00:00    99
# 2018-01-02 16:00:00    83
# 2018-01-02 17:00:00    12
# 2018-01-02 18:00:00    42
# 2018-01-02 19:00:00    58
# 2018-01-02 20:00:00    56
# 2018-01-02 21:00:00    73
# 2018-01-02 22:00:00    91
# 2018-01-02 23:00:00    30

# %%
df.loc["2018-01-03"]
# Out:
#                      data
# datetime
# 2018-01-03 00:00:00    85
# 2018-01-03 01:00:00    41
# 2018-01-03 02:00:00    52
# 2018-01-03 03:00:00     7
# 2018-01-03 04:00:00    65
# 2018-01-03 05:00:00    22
# 2018-01-03 06:00:00    56
# 2018-01-03 07:00:00    30
# 2018-01-03 08:00:00    67
# 2018-01-03 09:00:00    35
# 2018-01-03 10:00:00    69
# 2018-01-03 11:00:00    71
# 2018-01-03 12:00:00    25
# 2018-01-03 13:00:00    70
# 2018-01-03 14:00:00    79
# 2018-01-03 15:00:00    58
# 2018-01-03 16:00:00    47
# 2018-01-03 17:00:00    77
# 2018-01-03 18:00:00     5
# 2018-01-03 19:00:00    82
# 2018-01-03 20:00:00    96
# 2018-01-03 21:00:00    22
# 2018-01-03 22:00:00    12
# 2018-01-03 23:00:00     9

# %%
df["2018-01-04":"2018-01-06"]
# Out:
#                      data
# datetime
# 2018-01-04 00:00:00    39
# 2018-01-04 01:00:00    48
# 2018-01-04 02:00:00     8
# 2018-01-04 03:00:00    29
# 2018-01-04 04:00:00    22
# ...                   ...
# 2018-01-06 19:00:00    73
# 2018-01-06 20:00:00    96
# 2018-01-06 21:00:00    80
# 2018-01-06 22:00:00     2
# 2018-01-06 23:00:00    65
#
# [72 rows x 1 columns]

# %%
df.resample("D").mean()
# Out:
#                  data
# datetime
# 2018-01-01  51.375000
# 2018-01-02  52.125000
# 2018-01-03  49.250000
# 2018-01-04  52.416667
# 2018-01-05  43.333333
# 2018-01-06  50.583333
# 2018-01-07  44.333333
# 2018-01-08   3.000000

# %%
df.resample("Y").mean()
# Out:
#                  data
# datetime
# 2018-12-31  48.786982

# %%
df["rolling_sum"] = df.rolling(3).sum()
df.head(10)
# Out:
#                      data  rolling_sum
# datetime
# 2018-01-01 00:00:00     6          NaN
# 2018-01-01 01:00:00    51          NaN
# 2018-01-01 02:00:00    20         77.0
# 2018-01-01 03:00:00    57        128.0
# 2018-01-01 04:00:00    77        154.0
# 2018-01-01 05:00:00    77        211.0
# 2018-01-01 06:00:00     0        154.0
# 2018-01-01 07:00:00    51        128.0
# 2018-01-01 08:00:00    84        135.0
# 2018-01-01 09:00:00    71        206.0

# %%
df['rolling_sum_backfilled'] = df['rolling_sum'].fillna(method='backfill')
df.head(10)
# Out:
#                      data  rolling_sum  rolling_sum_backfilled
# datetime
# 2018-01-01 00:00:00     6          NaN                    77.0
# 2018-01-01 01:00:00    51          NaN                    77.0
# 2018-01-01 02:00:00    20         77.0                    77.0
# 2018-01-01 03:00:00    57        128.0                   128.0
# 2018-01-01 04:00:00    77        154.0                   154.0
# 2018-01-01 05:00:00    77        211.0                   211.0
# 2018-01-01 06:00:00     0        154.0                   154.0
# 2018-01-01 07:00:00    51        128.0                   128.0
# 2018-01-01 08:00:00    84        135.0                   135.0
# 2018-01-01 09:00:00    71        206.0                   206.0

# %%
# Here’s an example of a time t that is in Epoch time and converting unix/epoch time to a regular time stamp in UTC:
    
epoch_t = 1529272655

real_t = pd.to_datetime(epoch_t, unit='s')

real_t
# Out:
# Timestamp('2018-06-17 21:57:35')

# %%
# If I wanted to convert that time that is in UTC to my own time zone, I could simply do the following:

real_t.tz_localize('UTC').tz_convert('US/Pacific')
# Out:
# Timestamp('2018-06-17 14:57:35-0700', tz='US/Pacific')

# %%
import matplotlib 
# %matplotlib inline
matplotlib.rcParams["figure.figsize"]=[12.0,8.0]

# %%
data_set = pd.read_csv("international-airline-passengers.csv")
data_set.rename(columns={"International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60":"Passengers"},inplace=True)
data_set.head(10)
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121
# 5  1949-06         135
# 6  1949-07         148
# 7  1949-08         148
# 8  1949-09         136
# 9  1949-10         119

# %%
data_set.isnull().sum()
# Out:
# Month         0
# Passengers    0
# dtype: int64

# %%
data_set.fillna(method='ffill', inplace=True)

# %%
data_set.isnull().sum()
# Out:
# Month         0
# Passengers    0
# dtype: int64

# %%
data_set.dtypes
# Out:
# Month         object
# Passengers     int64
# dtype: object

# %%
data_set["Passengers"]=data_set["Passengers"].astype(int)

# %%
data_set.head(10)
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121
# 5  1949-06         135
# 6  1949-07         148
# 7  1949-08         148
# 8  1949-09         136
# 9  1949-10         119

# %%
data_set["Month"] = pd.to_datetime(data_set["Month"])
data_set.head()
# Out:
#        Month  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %%
data_set.dtypes
# Out:
# Month         datetime64[ns]
# Passengers             int32
# dtype: object

# %%
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %%
data_set = data_set.set_index("Month",inplace=True)

# %%
data_set
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %%
data_set.plot(grid=True);

# %%
start_date = datetime(1959,1,1)
end_date =datetime(1960,12,1)
data_set[(start_date<=data_set.index) & (data_set.index<=end_date)].plot(grid=True);

# %%
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(data_set, model ="additive")
fig = decomposition.plot()
matplotlib.rcParams["figure.figsize"] = [9.0,5.0]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

fig, ax = plt.subplots()
ax.grid(True)
year = mdates.YearLocator(month=1)
month = mdates.MonthLocator(interval=3)
year_format = mdates.DateFormatter('%Y')
month_format = mdates.DateFormatter('%m')
ax.xaxis.set_minor_locator(month)
ax.xaxis.grid(True, which = 'minor')
ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_format)
plt.plot(data_set.index, data_set['Passengers'], c='blue')
plt.plot(decomposition.trend.index, decomposition.trend, c='red');
